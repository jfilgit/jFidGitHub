# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Call the show function to show the result
plt.show()

# %%
import pandas as pd
seattle_weather = pd.read_csv('C:/Users/Juli/Downloads/seattle_weather')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/3369446341.py in <module>
#       1 import pandas as pd
# ----> 2 seattle_weather = pd.read_csv('C:/Users/Juli/Downloads/seattle_weather')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
seattle_weather = pd.read_csv(r'C:\Users\Juli\Downloads\seattle_weather')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/4173680463.py in <module>
# ----> 1 seattle_weather = pd.read_csv(r'C:\Users\Juli\Downloads\seattle_weather')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
seattle_weather = pd.read_csv(r'C:\Users\Juli\Downloads\seattle_weather.csv')

# %%
seattle_weather
# Out:
#          STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0    USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1    USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2    USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3    USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4    USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
# ..           ...                  ...   ...              ...              ...
# 199  USC00454169          KENT, WA US     8            673.0            518.0
# 200  USC00454169          KENT, WA US     9            493.0            344.0
# 201  USC00454169          KENT, WA US    10            248.0            118.0
# 202  USC00454169          KENT, WA US    11             78.0             19.0
# 203  USC00454169          KENT, WA US    12             22.0              2.0
#
# ...

# %%
austin_weather = pd.read_csv(r'C:\Users\Juli\Downloads\austin_weather.csv')

# %%
austin_weather
# Out:
#         STATION                                           NAME  DATE  \
# 0   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
# 5   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     6
# 6   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     7
# 7   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     8
# 8   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     9
# 9   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    10
# 10  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    11
# 11  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    12
#
# ...

# %%
#Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against MONTH
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"])

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"])

# Call the show function
plt.show()

# %%
# Plot Seattle data, setting data appearance
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"],
        color='b', marker='o', linestyle='--')

# Plot Austin data, setting data appearance
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"],
        color='r', marker='v', linestyle='--')

# Call show to display the resulting plot
plt.show()

# %%
#Import the matplotlib.pyplot submodule and name it plt
#import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against MONTH
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"])

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"])

# Call the show function
plt.show()

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against MONTH
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"],
        color='b', marker='o', linestyle='--')

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"],
        color='r', marker='v', linestyle='--')

# Call the show function
plt.show()

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"])
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"])

# Customize the x-axis label
ax.set_xlabel("Time (months)")

# Customize the y-axis label
ax.set_ylabel("Precipitation (inches)")

# Add the title
ax.set_title("Weather patterns in Austin and Seattle")

# Display the figure
plt.show()

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"])
ax.plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"])

# Customize the x-axis label
ax.set_xlabel("Time (months)")

# Customize the y-axis label
ax.set_ylabel("Precipitation (inches)")

# Add the title
ax.set_title("Weather patterns in Austin and Seattle")

# Display the figure
plt.show()

# %%
austin_weather
# Out:
#         STATION                                           NAME  DATE  \
# 0   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
# 5   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     6
# 6   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     7
# 7   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     8
# 8   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     9
# 9   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    10
# 10  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    11
# 11  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    12
#
# ...

# %%
# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
ax[0, 0].plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"])

# In the top right (index 0,1), plot month and Seattle temperatures
ax[0, 1].plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-PRBOCC-LSTH016"])

# In the bottom left (1, 0) plot month and Austin precipitations
ax[1, 0].plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"])

# In the bottom right (1, 1) plot month and Austin temperatures
ax[1, 1].plot(austin_weather["DATE"], austin_weather["MLY-TMIN-PRBOCC-LSTH016"])
plt.show()

# %%
# Create a figure and an array of axes: 2 rows, 1 column with shared y axis
fig, ax = plt.subplots(2, 1, sharey=True)

# Plot Seattle precipitation in the top axes
ax[0].plot(seattle_weather["DATE"], seattle_weather["MLY-TMIN-NORMAL"], color='b')
ax[0].plot(seattle_weather["DATE"], seattle_weather["MLY-CLDD-BASE45"], color='b', linestyle='--')
ax[0].plot(seattle_weather["DATE"], seattle_weather["MLY-CLDD-BASE70"], color='b', linestyle='--')

# Plot Austin precipitation in the bottom axes
ax[1].plot(austin_weather["DATE"], austin_weather["MLY-TMIN-NORMAL"], color='r')
ax[1].plot(austin_weather["DATE"], austin_weather["MLY-CLDD-BASE45"], color='r', linestyle='--')
ax[1].plot(austin_weather["DATE"], austin_weather["MLY-CLDD-BASE70"], color='r', linestyle='--')

plt.show()

# %%
# Import pandas
import pandas as pd

# Read the data from file using read_csv
climate_change = pd.read_csv(r'C:\Users\Juli\Downloads\climate_change.csv', parse_dates=["date"], index_col="date")

# %%
climate_change
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06
# ...            ...            ...
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81
#
# [706 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index, climate_change['relative_temp'])

# Set the x-axis label
ax.set_xlabel('Time')

# Set the y-axis label 
ax.set_ylabel('Relative temperature (Celsius)')

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt

# Use plt.subplots to create fig and ax
#fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %%
#import matplotlib.pyplot as plt

# Use plt.subplots to create fig and ax
#fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt

# Use plt.subplots to create fig and ax
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt

# Initalize a Figure and Axes
fig, ax = plt.subplots()

# Plot the CO2 variable in blue
ax.plot(climate_change.index, climate_change["co2"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature in red
ax2.plot(climate_change.index, climate_change["relative_temp"], color='red')

plt.show()

# %%
# Define a function called plot_timeseries
def plot_timeseries(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x,y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', "Time (years)", "CO2 levels")

# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', "Time (years)", "Relative temperature (Celsius)")

plt.show()

# %%
fig, ax = plt.subplots()

# Plot the relative temperature data
ax.plot(climate_change.index, climate_change['relative_temp'])

# Annotate the date at which temperatures exceeded 1 degree
ax.annotate(">1 degree", xy=(pd.Timestamp('2015-10-06'), 1))

plt.show()

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', "Time (years)", "CO2 levels")

# Create an Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', "Time (years)", "Relative temp (Celsius)")

# Annotate the point with relative temperature >1 degree
ax2.annotate(">1 degree", xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2), arrowprops={'arrowstyle':'->', 'color':'gray'})

plt.show()

# %%
# Import pandas
import pandas as pd

# Read the data from file using read_csv
medals = pd.read_csv(r'C:\Users\Juli\Downloads\medals_by_country_2016.csv', index_col=0)

# %%
medals
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30
# France             21    20      55
# Australia          25    23      34
# Italy              24     8      38
# Canada             61     4       4
# Japan              34    17      13

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel("Number of medals")

plt.show()
# Out:
# C:\Users\Juli\AppData\Local\Temp/ipykernel_8916/1552821526.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel("Number of medals")

plt.show()
# Out:
# C:\Users\Juli\AppData\Local\Temp/ipykernel_8916/1552821526.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)


# Set the y-axis label
ax.set_ylabel("Number of medals")


# Display the legend
ax.legend()


plt.show()
# Out:
# C:\Users\Juli\AppData\Local\Temp/ipykernel_8916/4135945419.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %%
# Import pandas
import pandas as pd

# Read the data from file using read_csv
olympics = pd.read_csv(r'C:\Users\Juli\Downloads\summer2016.csv')

# %%
olympics
# Out:
#       Unnamed: 0      ID                             Name Sex   Age  Height  \
# 0            158      62                Giovanni Abagnale   M  21.0   198.0
# 1            161      65                Patimat Abakarova   F  21.0   165.0
# 2            175      73                        Luc Abalo   M  31.0   182.0
# 3            450     250             Saeid Morad Abdevali   M  26.0   170.0
# 4            794     455      Denis Mikhaylovich Ablyazin   M  24.0   161.0
# ...          ...     ...                              ...  ..   ...     ...
# 2009      269511  134857                         Zhu Ting   F  21.0   198.0
# 2010      270111  135132                    Bojana ivkovi   F  28.0   186.0
# 2011      270281  135205  Shakhobiddin Shokirovich Zoirov   M  23.0   169.0
# 2012      270370  135245                     Milenko Zori   M  27.0   179.0
# 2013      271019  135525                   Martin Zwicker   M  29.0   175.0
#
# ...

# %%
mens_rowing = olympics[olympics["Sport"] == "Rowing"]

#data_set[data_set[col_idx] < value]

# %%
mens_rowing
# Out:
#       Unnamed: 0      ID                     Name Sex   Age  Height  Weight  \
# 0            158      62        Giovanni Abagnale   M  21.0   198.0    90.0
# 10          1228     690       Chantal Achterberg   F  31.0   172.0    72.0
# 52          6598    3691      Anne Dsane Andersen   F  23.0   183.0    86.0
# 78         11648    6346               Jrmie Azou   M  27.0   178.0    71.0
# 89         14103    7612                Carina Br   F  26.0   185.0    75.0
# ...          ...     ...                      ...  ..   ...     ...     ...
# 1905      258859  129601           Phillipp Wende   M  31.0   199.0    90.0
# 1919      260260  130259   Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 1920      260338  130298              Tone Wieten   M  22.0   201.0   102.0
# 1934      261547  130868      Melanie Kate Wilson   F  32.0   184.0    75.0
# 1937      261973  131072  Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mens_rowing = olympics.loc[["Sport"] == "Rowing"]

#data_set[data_set[col_idx] < value]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/797753879.py in <module>
# ----> 1 mens_rowing = olympics.loc[["Sport"] == "Rowing"]
#       2
#       3 #data_set[data_set[col_idx] < value]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1161
#    1162         # fall thru to straight lookup
# -> 1163         self._validate_key(key, axis)
#    1164         return self._get_label(key, axis=axis)
#    1165
#
# ...

# %%
mens_rowing = olympics.loc[:,["Sport"] == "Rowing"]

#data_set[data_set[col_idx] < value]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/2918093697.py in <module>
# ----> 1 mens_rowing = olympics.loc[:,["Sport"] == "Rowing"]
#       2
#       3 #data_set[data_set[col_idx] < value]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
# ...

# %%
mens_rowing = olympics.loc[olympics["Sport"] == "Rowing"]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]

# %%
mens_rowing
# Out:
#       Unnamed: 0      ID                     Name Sex   Age  Height  Weight  \
# 0            158      62        Giovanni Abagnale   M  21.0   198.0    90.0
# 10          1228     690       Chantal Achterberg   F  31.0   172.0    72.0
# 52          6598    3691      Anne Dsane Andersen   F  23.0   183.0    86.0
# 78         11648    6346               Jrmie Azou   M  27.0   178.0    71.0
# 89         14103    7612                Carina Br   F  26.0   185.0    75.0
# ...          ...     ...                      ...  ..   ...     ...     ...
# 1905      258859  129601           Phillipp Wende   M  31.0   199.0    90.0
# 1919      260260  130259   Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 1920      260338  130298              Tone Wieten   M  22.0   201.0   102.0
# 1934      261547  130868      Melanie Kate Wilson   F  32.0   184.0    75.0
# 1937      261973  131072  Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
# ...

# %%
mens_rowing = olympics.loc[["Sport"] == "Rowing"]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/99979545.py in <module>
# ----> 1 mens_rowing = olympics.loc[["Sport"] == "Rowing"]
#       2
#       3 #data_set[data_set[col_idx] < value]
#       4 #below_df = df.loc[df[col_idx]<=value]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1161
#    1162         # fall thru to straight lookup
# -> 1163         self._validate_key(key, axis)
#    1164         return self._get_label(key, axis=axis)
#    1165
#
# ...

# %%
#mens_rowing = olympics.loc[["Sport"] == "Rowing"]

mens_rowing = olympics.iloc[: , [14]]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
#new = old.iloc[: , [1, 6, 7]].copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1425         else:
# -> 1426             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1427
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/2347339452.py in <module>
# ...

# %%
#mens_rowing = olympics.loc[["Sport"] == "Rowing"]

mens_rowing = olympics.iloc[: , [14]]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
#new = old.iloc[: , [1, 6, 7]].copy()

# %%
mens_rowing
# Out:
#                                            Event
# 0                     Rowing Men's Coxless Pairs
# 1                    Taekwondo Women's Flyweight
# 2                        Handball Men's Handball
# 3      Wrestling Men's Middleweight, Greco-Roman
# 4               Gymnastics Men's Team All-Around
# ...                                          ...
# 2009               Volleyball Women's Volleyball
# 2010               Volleyball Women's Volleyball
# 2011                      Boxing Men's Flyweight
# 2012  Canoeing Men's Kayak Doubles, 1,000 metres
# 2013                         Hockey Men's Hockey
#
# [2014 rows x 1 columns]

# %%
#mens_rowing = olympics.loc[["Sport"] == "Rowing"]

mens_rowing = olympics.iloc[: , [13]]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
#new = old.iloc[: , [1, 6, 7]].copy()

# %%
mens_rowing
# Out:
#            Sport
# 0         Rowing
# 1      Taekwondo
# 2       Handball
# 3      Wrestling
# 4     Gymnastics
# ...          ...
# 2009  Volleyball
# 2010  Volleyball
# 2011      Boxing
# 2012    Canoeing
# 2013      Hockey
#
# [2014 rows x 1 columns]

# %%
#mens_rowing = olympics.loc[["Sport"] == "Rowing"]

#mens_rowing = olympics.iloc[: , [13]]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
#new = old.iloc[: , [1, 6, 7]].copy() 



mens_rowing2 = olympics[(olympics['Sport'] == "Rowing") ]

# %%
mens_rowing2
# Out:
#       Unnamed: 0      ID                     Name Sex   Age  Height  Weight  \
# 0            158      62        Giovanni Abagnale   M  21.0   198.0    90.0
# 10          1228     690       Chantal Achterberg   F  31.0   172.0    72.0
# 52          6598    3691      Anne Dsane Andersen   F  23.0   183.0    86.0
# 78         11648    6346               Jrmie Azou   M  27.0   178.0    71.0
# 89         14103    7612                Carina Br   F  26.0   185.0    75.0
# ...          ...     ...                      ...  ..   ...     ...     ...
# 1905      258859  129601           Phillipp Wende   M  31.0   199.0    90.0
# 1919      260260  130259   Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 1920      260338  130298              Tone Wieten   M  22.0   201.0   102.0
# 1934      261547  130868      Melanie Kate Wilson   F  32.0   184.0    75.0
# 1937      261973  131072  Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
# ...

# %%
#mens_rowing = olympics.loc[["Sport"] == "Rowing"]

#mens_rowing = olympics.iloc[: , [13]]

#data_set[data_set[col_idx] < value]
#below_df = df.loc[df[col_idx]<=value]
#new = old.iloc[: , [1, 6, 7]].copy() 



mens_rowing2 = olympics['Sport'] == "Rowing"
# Out:
#   File "C:\Users\Juli\AppData\Local\Temp/ipykernel_8916/2948050828.py", line 11
#     mens_rowing2 = olympics['Sport'] == "Rowing
#                                                ^
# SyntaxError: EOL while scanning string literal

# %%
mens_rowing2 = olympics['Sport'] == "Rowing"

# %%
mens_rowing2
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2009    False
# 2010    False
# 2011    False
# 2012    False
# 2013    False
# Name: Sport, Length: 2014, dtype: bool

# %%
mens_rowing2 = olympics[['Sport'] == "Rowing"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing"]

# %%
# Out:
#       Unnamed: 0      ID                     Name Sex   Age  Height  Weight  \
# 0            158      62        Giovanni Abagnale   M  21.0   198.0    90.0
# 10          1228     690       Chantal Achterberg   F  31.0   172.0    72.0
# 52          6598    3691      Anne Dsane Andersen   F  23.0   183.0    86.0
# 78         11648    6346               Jrmie Azou   M  27.0   178.0    71.0
# 89         14103    7612                Carina Br   F  26.0   185.0    75.0
# ...          ...     ...                      ...  ..   ...     ...     ...
# 1905      258859  129601           Phillipp Wende   M  31.0   199.0    90.0
# 1919      260260  130259   Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 1920      260338  130298              Tone Wieten   M  22.0   201.0   102.0
# 1934      261547  130868      Melanie Kate Wilson   F  32.0   184.0    75.0
# 1937      261973  131072  Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
# ...

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing",['Sport']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/1403020217.py in <module>
# ----> 1 mens_rowing2 = olympics[olympics['Sport'] == "Rowing",['Sport']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing",oluympics['Sport']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/1118273323.py in <module>
# ----> 1 mens_rowing2 = olympics[olympics['Sport'] == "Rowing",oluympics['Sport']]
#
# NameError: name 'oluympics' is not defined

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing",olympics['Sport']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/1597327591.py in <module>
# ----> 1 mens_rowing2 = olympics[olympics['Sport'] == "Rowing",olympics['Sport']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
mens_rowing2 = olympics[[olympics['Sport'] == "Rowing"], [olympics['Sport']]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/3008001648.py in <module>
# ----> 1 mens_rowing2 = olympics[[olympics['Sport'] == "Rowing"], [olympics['Sport']]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/1289655535.py in <module>
# ----> 1 mens_rowing2 = olympics[[olympics['Sport'] == "Rowing"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
mens_rowing2 = olympics[olympics['Sport'] == "Rowing"]

# %%
mens_rowing2
# Out:
#       Unnamed: 0      ID                     Name Sex   Age  Height  Weight  \
# 0            158      62        Giovanni Abagnale   M  21.0   198.0    90.0
# 10          1228     690       Chantal Achterberg   F  31.0   172.0    72.0
# 52          6598    3691      Anne Dsane Andersen   F  23.0   183.0    86.0
# 78         11648    6346               Jrmie Azou   M  27.0   178.0    71.0
# 89         14103    7612                Carina Br   F  26.0   185.0    75.0
# ...          ...     ...                      ...  ..   ...     ...     ...
# 1905      258859  129601           Phillipp Wende   M  31.0   199.0    90.0
# 1919      260260  130259   Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 1920      260338  130298              Tone Wieten   M  22.0   201.0   102.0
# 1934      261547  130868      Melanie Kate Wilson   F  32.0   184.0    75.0
# 1937      261973  131072  Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
# ...

# %%
mens_rowing2 = olympics.loc[olympics['Sport'] == "Rowing", 'Sport']

#titanic.loc[titanic["Age"] > 35, "Name"]

# %%
mens_rowing2
# Out:
# 0       Rowing
# 10      Rowing
# 52      Rowing
# 78      Rowing
# 89      Rowing
#          ...
# 1905    Rowing
# 1919    Rowing
# 1920    Rowing
# 1934    Rowing
# 1937    Rowing
# Name: Sport, Length: 144, dtype: object

# %%
mens_rowing2 = olympics.loc[olympics['Sport'] == "Rowing", 'Weight']

# %%
mens_rowing2
# Out:
# 0        90.0
# 10       72.0
# 52       86.0
# 78       71.0
# 89       75.0
#         ...
# 1905     90.0
# 1919     55.0
# 1920    102.0
# 1934     75.0
# 1937     73.0
# Name: Weight, Length: 144, dtype: float64

# %%
mens_rowing2 = olympics.loc[olympics['Sport'] == "Rowing", ['Weight']]

# %%
mens_rowing2
# Out:
#       Weight
# 0       90.0
# 10      72.0
# 52      86.0
# 78      71.0
# 89      75.0
# ...      ...
# 1905    90.0
# 1919    55.0
# 1920   102.0
# 1934    75.0
# 1937    73.0
#
# [144 rows x 1 columns]

# %%
type(mens_rowing2)
# Out:
# pandas.core.frame.DataFrame
